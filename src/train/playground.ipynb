# %%
import os 
import pandas as pd
notebook_dir = os.getcwd()
data_path = os.path.abspath(os.path.join(notebook_dir, "..", "..", "data", "processed", "pr_snapshots_clean_v2.csv"))

# 3. Read the file
df = pd.read_csv(data_path)

# %%
df.dtypes
# Out:
# pr_id                          int64
# owner                         object
# name                          object
# number                         int64
# checkpoint_day                 int64
# days_elapsed                   int64
# additions                      int64
# deletions                      int64
# changed_files                  int64
# title_length                   int64
# author_login                  object
# author_type                   object
# num_labels                     int64
# created_dow                    int64
# created_hour                   int64
# comments_so_far                int64
# reviews_so_far                 int64
# reviewer_assigned              int64
# first_response_hours         float64
# timeline_data_available        int64
# merged_before_next             int64
# additions_norm               float64
# deletions_norm               float64
# changed_files_norm           float64
# has_response_yet               int64
# repo_key                      object
# author_prior_pr_count          int64
# author_prior_merge_rate      float64
# is_first_time_contributor      int64
# repo_prior_pr_count            int64
# repo_prior_merge_rate        float64
# created_at_day                 int64
# created_at_month               int64
# dtype: object
